# %% [markdown]
# # Terrabot Project Software
#
# ## Tasks that must be complted:
# - [] Implement a mainframe (C++)
# - [] Implement computer vision detection for snow (python using YoLo for real time detection)
# - [] Implement actuation system for snow removal (C++)
# - [] Implement path planning and navigation (python for distance/path alignment, C++ for actuation control)
